# %%
import fastai
from fastai.tabular import *
import pandas as pd

# %%
df = pd.read_csv('../input/marketingrar/marketing.csv')
df.head()
# Out:
#          Date  Week  Week_ID  Month  Month_ID  Year   Day_Name  Visitors  \
# 0  09/11/2020    46       34     11        11  2020     Monday       707
# 1  10/11/2020    46       34     11        11  2020    Tuesday      1455
# 2  11/11/2020    46       34     11        11  2020  Wednesday      1520
# 3  12/11/2020    46       34     11        11  2020   Thursday      1726
# 4  13/11/2020    46       34     11        11  2020     Friday      2134
#
#    Revenue  Marketing Spend           Promo
# 0      465          651.375        No Promo
# 1    10386         1298.250   Promotion Red
# 2    12475         1559.375  Promotion Blue
# 3    11712         1801.750        No Promo
# 4    10000         2614.500        No Promo

# %%
df.dtypes
# Out:
# Date                object
# Week                 int64
# Week_ID              int64
# Month                int64
# Month_ID             int64
# Year                 int64
# Day_Name            object
# Visitors             int64
# Revenue              int64
# Marketing Spend    float64
# Promo               object
# dtype: object

# %%
df.shape
# Out:
# (182, 11)

# %%
dep_var = 'Visitors'
cat_names = ['Date','Day_Name','Promo']
cont_names = ['Week','Month','Year','Revenue','Marketing Spend']
procs = [FillMissing, Categorify, Normalize]

# %%
data = (TabularList.from_df(df, cat_names=cat_names, cont_names=cont_names, procs=procs)
       .split_by_idx(valid_idx=())
       .label_from_df(cols=dep_var)
       .databunch())

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date</th>
#       <th>Day_Name</th>
#       <th>Promo</th>
#       <th>Week</th>
#       <th>Month</th>
#       <th>Year</th>
#       <th>Revenue</th>
#       <th>Marketing Spend</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>07/12/2020</td>
#       <td>Monday</td>
#       <td>Promotion Red</td>
#       <td>1.5359</td>
#       <td>1.6008</td>
#       <td>-1.5558</td>
#       <td>-0.1540</td>
#       <td>-0.6290</td>
#       <td>1584</td>
#     </tr>
#     <tr>
#       <td>04/04/2021</td>
#       <td>Sunday</td>
#       <td>No Promo</td>
#       <td>-0.3694</td>
#       <td>-0.3019</td>
#       <td>0.6392</td>
#       <td>-0.6659</td>
#       <td>-0.9277</td>
#       <td>1406</td>
#     </tr>
#     <tr>
#       <td>10/11/2020</td>
#       <td>Tuesday</td>
#       <td>Promotion Red</td>
#       <td>1.3182</td>
#       <td>1.3630</td>
# ...

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit_one_cycle(30, 1e-2)
learn.save('mini_train')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.299532</td>
#       <td>5.165226</td>
#       <td>0.016484</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.246889</td>
#       <td>5.157977</td>
#       <td>0.016484</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.151809</td>
#       <td>5.140732</td>
#       <td>0.027473</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.020618</td>
#       <td>5.107190</td>
#       <td>0.032967</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.886524</td>
#       <td>5.048290</td>
#       <td>0.043956</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.show_results()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ca4457400b7d> in <module>
# ----> 1 learner.show_result()
#
# NameError: name 'learner' is not defined
